# %% [markdown]
# # [NWML24] Project
#
# TAs: [Ali Hariri](ali.hariri@epfl.ch) and [Ortal Senouf](ortal.senouf@epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: 5
# * Students: Hans Kristian Bjorgo Kvaerum (), Kaede Johnson (357472)

# %% [markdown]
# ## Tasks
# 1. Explore data and demonstrate we understand its structure
# 2. Build a hand-crafted feature model based on our network
# 3. Build an unsupervised GNN method
